# %%
import codecs

# %%
train_filepath = '../../../ML_EntityData/data/vi/valid.txt'
train_out = '../../../ML_EntityData/data/vi/valid_out.txt'

# %%
with codecs.open(train_out,'w','utf-8') as out:
    file = codecs.open(train_filepath,'r','utf-8')
    out.write(file.read().replace('\t',' '))
    file.close()

# %%
file.read().replace('\t',' ')
# Out:
# 'Đó P B-NP O\r\nlà V B-VP O\r\ncon Nc B-NP O\r\nđường N B-NP O\r\nbiển N B-NP O\r\nngắn A B-AP O\r\nnhất A B-AP O\r\nđể E B-PP O\r\nđi V B-VP O\r\ntừ E B-PP O\r\nẤn_Độ_Dương NNP B-NP B-LOC\r\nsang V B-VP O\r\nThái_Bình_Dương NNP B-NP B-LOC\r\n, CH O O\r\nchiếm V B-VP O\r\nđến E B-PP O\r\nlượng N B-NP O\r\nhàng_hoá N B-NP O\r\nlưu_thông V B-VP O\r\nđường_biển N B-NP O\r\ncủa E B-PP O\r\nthế_giới N B-NP O\r\n, CH O O\r\nđó P B-NP O\r\nlà V B-VP O\r\nhải_trình N B-NP O\r\nlớn A B-AP O\r\nnhất R O O\r\ntừ E B-PP O\r\ntây N B-NP O\r\nsang V B-VP O\r\nđông N B-NP O\r\nvới E B-PP O\r\n50.000 M B-NP O\r\nlượt Nc B-NP O\r\ntàu_bè N B-NP O\r\nqua_lại V B-VP O\r\nmỗi L B-NP O\r\nnăm N B-NP O\r\n... CH O O\r\n\r\nMột M B-NP O\r\nchuyến N B-NP O\r\nhải_trình N B-NP O\r\nxuyên V B-VP O\r\nba M B-NP O\r\nnước N B-NP O\r\nMalaysia NNP B-NP B-LOC\r\n, CH O O\r\nSingapore NNP B-NP B-LOC\r\n, CH O O\r\nIndonesia NNP B-NP B-LOC\r\nvừa R O O\r\nđược V B-VP O\r\nphóng_viên N B-NP O\r\nTuổi_Trẻ NNP B-NP B-
# ...

# %%
import tensorflow as tf
import numpy as np

# %%
x=tf.placeholder(tf.float32,shape=[None,5])
y=tf.placeholder(tf.float32,shape=[None])
W = tf.Variable(np.random.randn(5),dtype=tf.float32)
cost=tf.reduce_sum(tf.sigmoid(tf.abs(W*x-y)))
optimizer = tf.train.GradientDescentOptimizer(0.1).minimize(cost)
init = tf.global_variables_initializer()

# %%
with tf.Session() as sess:
    sess.run(init)
    sess.run(optimizer,feed_dict={x:[[1,2,3,4,5],[2,3,4,5,6]],y:[5,6]})
    print(sess.run(W))
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# d:\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#
# d:\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#
# d:\programs\python\python36\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
# ...
